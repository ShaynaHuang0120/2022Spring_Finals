# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import Final_code as fn

# %%
pitstops_file = fn.read_data("data/pit_stops.csv")

# %%
results_file = fn.read_data("data/results.csv")

# %%
races_file = fn.read_data("data/races.csv")

# %%
total_pitstop = fn.total_pitstop(pitstops_file)

# %%
process = fn.data_process(results_file, "position", "\\N")

# %%
fn.pitstop_boxplot(total_pitstop, process, ["raceId", "driverId"],["stop", "position"])
# boxplot_data.plot()
# plt.show()

# %%
combined_table = fn.tables_combined(process,total_pitstop, races_file, ["raceId", "driverId"], ['raceId'], 10)
fn.stop_chart(combined_table, 3)
