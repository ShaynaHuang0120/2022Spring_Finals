# %% [markdown]
# # Pit Stop Data Analysis Notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import final_func as fn

# %%
# reload Module
import importlib
importlib.reload(fn)
# Out:
# <module 'final_func' from '/Users/pigggy/PycharmProjects/2022Spring_Finals 3/final_func.py'>

# %% [markdown]
# # Data Preparation

# %%
# Load data
results = pd.read_csv('data/results.csv')
lap = pd.read_csv("data/lap_times.csv")

# %%
#Process the data files
lap_df = fn.lap_data_process(results, lap)

# %% [markdown]
# # Hypothesis 4

# %%
fn.barchart_lapspeed(lap_df)

# %%
fn.rank_df_plt(lap_df)
# Out:
# H0: There is no significant difference in the distribution of lap times STD between the ranking of drivers.
# ----------------------------------------------------------------------------------------
# P-value between high ranking drivers and low ranking drivers is 0.30846789394625385.
# ----------------------------------------------------------------------------------------
# H0 cannot be rejected
